# %%
import yfinance as yf
print("yfinance installed successfully")
# Out:
# yfinance installed successfully

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\asus\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (4.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\asus\anaconda3\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\asus\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\asus\anaconda3\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\asus\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in c:\users\asus\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)

# %%
import os
import yfinance as yf
import pandas as pd

# ==============================
# 1. CONFIGURATION
# ==============================
ticker_symbol = "TCS.NS"      # Example: TCS on NSE
start_date = "2018-01-01"
end_date = "2025-12-31"
save_path = "../data/raw/tcs_stock_data.csv"

# ==============================
# 2. CREATE FOLDER IF NOT EXISTS
# ==============================
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# ==============================
# 3. DOWNLOAD STOCK DATA
# ==============================
df = yf.download(
    ticker_symbol,
    start=start_date,
    end=end_date,
    auto_adjust=False,
    progress=False
)

# ==============================
# 4. HANDLE EMPTY DATA
# ==============================
if df.empty:
    raise ValueError(f"No data found for ticker: {ticker_symbol}")

# ==============================
# 5. RESET INDEX
# ==============================
df.reset_index(inplace=True)

# ==============================
# 6. FLATTEN COLUMNS IF NEEDED
# ==============================
if isinstance(df.columns, pd.MultiIndex):
    df.columns = [col[0] if isinstance(col, tuple) else col for col in df.columns]

# ==============================
# 7. KEEP REQUIRED COLUMNS
# ==============================
required_columns = ["Date", "Open", "High", "Low", "Close", "Volume"]
df = df[required_columns]

# ==============================
# 8. BASIC INFO
# ==============================
print("Dataset Shape:", df.shape)
print("\nFirst 5 Rows:")
print(df.head())

print("\nColumn Names:")
print(df.columns.tolist())

print("\nMissing Values:")
print(df.isnull().sum())

# ==============================
# 9. SAVE TO CSV
# ==============================
df.to_csv(save_path, index=False)

print(f"\nDataset saved successfully at: {save_path}")
# Out:
# Dataset Shape: (1975, 6)
#
# First 5 Rows:
#         Date         Open         High          Low        Close   Volume
# 0 2018-01-01  1341.150024  1347.400024  1317.500000  1322.800049  1351760
# 1 2018-01-02  1330.000000  1334.800049  1310.099976  1315.599976  1920290
# 2 2018-01-03  1316.000000  1334.500000  1315.599976  1319.324951  1257120
# 3 2018-01-04  1325.000000  1331.000000  1320.000000  1328.550049   913082
# 4 2018-01-05  1325.000000  1349.750000  1325.000000  1344.599976  1153706
#
# Column Names:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
#
# Missing Values:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64
#
# Dataset saved successfully at: ../data/raw/tcs_stock_data.csv
