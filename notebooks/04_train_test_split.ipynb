# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/tcs_stock_features.csv")

df["Date"] = pd.to_datetime(df["Date"])
df = df.set_index("Date")

print(df.shape)
df.head()
# Out:
# (1921, 21)
#                    Open         High          Low        Close   Volume  \
# Date
# 2018-03-14  1446.474976  1461.525024  1437.525024  1443.449951  3668668
# 2018-03-15  1447.500000  1451.275024  1427.800049  1434.849976  2348906
# 2018-03-16  1434.400024  1436.000000  1402.500000  1412.849976  7197482
# 2018-03-19  1414.500000  1424.000000  1410.000000  1415.500000  3489940
# 2018-03-20  1410.000000  1436.599976  1409.500000  1432.425049  4024984
#
#                    MA20         MA50  Daily_Return  Volatility        lag_1  \
# Date
# 2018-03-14  1499.853760  1476.552009      0.000035    0.017597  1443.400024
# 2018-03-15  1498.801257  1478.793008     -0.005958    0.017155  1443.449951
# 2018-03-16  1496.297504  1480.738008     -0.015333    0.017411  1434.849976
# 2018-03-19  1493.746252  1482.661509      0.001876    0.017404  1412.849976
# 2018-03-20  1492.277502  1484.739009      0.011957    0.017660  1415.500000
#
#             ...        lag_3        lag_5       lag_10  rolling_mean_5  \
# Date        ...
# 2018-03-14  ...  1517.050049  1513.724976  1521.175049     1486.389990
# 2018-03-15  ...  1526.074951  1501.974976  1517.525024     1472.964990
# 2018-03-16  ...  1443.400024  1517.050049  1518.849976     1452.124976
# 2018-03-19  ...  1443.449951  1526.074951  1552.925049     1430.009985
# 2018-03-20  ...  1434.849976  1443.400024  1521.400024     1427.814990
#
#             rolling_mean_10  rolling_std_5  rolling_std_10    momentum  \
# Date
# 2018-03-14      1505.637500      40.155358       35.226259  -70.275024
# 2018-03-15      1497.369995      44.615411       41.303817  -67.125000
# 2018-03-16      1486.769995      43.188340       48.204071 -104.200073
# 2018-03-19      1473.027490      14.902659       46.817671 -110.574951
# 2018-03-20      1464.129993      13.141597       45.023513  -10.974976
#
#             price_change       target
# Date
# 2018-03-14     -3.025024  1428.375000
# 2018-03-15    -12.650024  1415.675049
# 2018-03-16    -21.550049  1409.074951
# 2018-03-19      1.000000  1408.500000
# 2018-03-20     22.425049  1423.849976
#
# [5 rows x 21 columns]

# %%
features = [
    "Open",
    "High",
    "Low",
    "Close",
    "Volume",
    "MA20",
    "MA50",
    "Daily_Return",
    "Volatility",
    "lag_1",
    "lag_2",
    "lag_3",
    "lag_5",
    "lag_10",
    "rolling_mean_5",
    "rolling_mean_10",
    "rolling_std_5",
    "rolling_std_10",
    "momentum",
    "price_change"
]

target = "target"

# %%
split_index = int(len(df) * 0.8)

train = df.iloc[:split_index]
test = df.iloc[split_index:]

# %%
X_train = train[features]
y_train = train[target]

# %%
X_test = test[features]
y_test = test[target]

# %%
print("Training set size:", X_train.shape)
print("Testing set size:", X_test.shape)
# Out:
# Training set size: (1536, 20)
# Testing set size: (385, 20)

# %%
print("Training period:")
print(train.index.min(), "to", train.index.max())

print("Testing period:")
print(test.index.min(), "to", test.index.max())
# Out:
# Training period:
# 2018-03-14 00:00:00 to 2024-06-05 00:00:00
# Testing period:
# 2024-06-06 00:00:00 to 2025-12-22 00:00:00

# %%
train.to_csv("../data/processed/train_data.csv")
test.to_csv("../data/processed/test_data.csv")
